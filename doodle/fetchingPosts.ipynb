# %%
##============ Dependencies and libraries ============##

from dotenv import load_dotenv
from bsky_bridge import BskySession
import os
import time
from atproto import Client
import requests
import datetime
import json


# Load environment variables from the .env file
load_dotenv()

# Retrieve credentials from environment variables
email = os.getenv('BLUESKY_EMAIL')
password = os.getenv('BLUESKY_PASSWORD')

# Create a session
session = BskySession(email, password)

# Verify session
if session.access_token:
    print("Authenticated successfully!")
else:
    print("Authentication failed.")

# Initialize the client and log in securely
client = Client("https://bsky.social")
response = client.login(email, password)

# Access and print the DID and handle directly
did = response.did
handle = response.handle

print(f"Response: {response}")
print(f"DID: {did}")
print(f"Handle: {handle}")

print("Authentication successful!")
# Out:
# Authenticated successfully!
# Response: did='did:plc:f6fle6xy5s4epqamivy45kfm' handle='mechfortuneteller.bsky.social' associated=ProfileAssociated(chat=None, feedgens=0, labeler=False, lists=0, starter_packs=0, py_type='app.bsky.actor.defs#profileAssociated') avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:f6fle6xy5s4epqamivy45kfm/bafkreiak7eaknki3ulkp4zqudfq2zymfnklchqam3leapdv4zxbrbavz7u@jpeg' banner=None created_at='2024-12-01T09:40:56.046Z' description=None display_name='' followers_count=3 follows_count=1 indexed_at='2024-12-01T09:40:56.046Z' joined_via_starter_pack=None labels=[] pinned_post=None posts_count=3 viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following=None, known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState') py_type='app.bsky.actor.defs#profileViewDetailed'
# DID: did:plc:f6fle6xy5s4epqamivy45kfm
# Handle: mechfortuneteller.bsky.social
# Authentication successful!

# %%
##============ New post ============##

from bsky_bridge import post_text

response = post_text(session, "Hello BlueSky!")
print(response)
# Out:
# {'uri': 'at://did:plc:f6fle6xy5s4epqamivy45kfm/app.bsky.feed.post/3lcq4auf6t22m', 'cid': 'bafyreifsiprporozd37hdqb4evxwr3m3fl7tmgtigm2zgpkjybasxtbfgm', 'commit': {'cid': 'bafyreiarlvmaorfglxhl6krtmoqa2snyznoqg6sgebrxgbpq2p4zntpjw4', 'rev': '3lcq4aufbqs2m'}, 'validationStatus': 'valid'}

# %%
##============ bsky_bridge library ============##

print(bsky_bridge.__file__)
bsky_bridge_dir = dir(bsky_bridge)
print(bsky_bridge_dir)

for directiory in bsky_bridge_dir:
    print(f" {directiory} : {dir(directiory)}")
# Out:
# /opt/homebrew/anaconda3/envs/mechanical-fortune-teller/lib/python3.13/site-packages/bsky_bridge/__init__.py
# ['BskySession', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', 'bsky_session', 'image_utilities', 'post_image', 'post_text', 'post_utilities']
#  BskySession : ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']
#  __builtins__ : ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']
#  __cached__ : ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']
#  __doc__ : ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']
#  __file__ : ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']
#  __loader__ : ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']
#  __name__ : ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']
#  __package__ : ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']
#  __path__ : ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']
#  __spec__ : ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']
#  bsky_session : ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']
#  image_utilities : ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']
#  post_image : ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']
#  post_text : ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']
#  post_utilities : ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %%
# Ensure successful authentication
if session.access_token:
    print("Authenticated successfully!")

    # Prepare headers with Bearer token
    headers = {"Authorization": f"Bearer {session.access_token}"}

    # Make the API request to fetch your timeline feed
    response = requests.get("https://bsky.social/xrpc/app.bsky.feed.getTimeline", headers=headers)

    if response.status_code == 200:
        feed = response.json().get("feed", [])
        
        # Print the first post's data to inspect its structure
        if feed:
            # Format JSON with indentation
            formatted_json = json.dumps(feed, indent=4)
            print(formatted_json)

    else:
        print("Failed to fetch feed:", response.status_code, response.text)
else:
    print("Authentication failed.")
# Out:
# Authenticated successfully!
# [
#     {
#         "post": {
#             "uri": "at://did:plc:f6fle6xy5s4epqamivy45kfm/app.bsky.feed.post/3lcq4auf6t22m",
#             "cid": "bafyreifsiprporozd37hdqb4evxwr3m3fl7tmgtigm2zgpkjybasxtbfgm",
#             "author": {
#                 "did": "did:plc:f6fle6xy5s4epqamivy45kfm",
#                 "handle": "mechfortuneteller.bsky.social",
#                 "displayName": "",
#                 "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:f6fle6xy5s4epqamivy45kfm/bafkreiak7eaknki3ulkp4zqudfq2zymfnklchqam3leapdv4zxbrbavz7u@jpeg",
#                 "viewer": {
#                     "muted": false,
#                     "blockedBy": false
#                 },
#                 "labels": [],
#                 "createdAt": "2024-12-01T09:40:56.046Z"
#             },
#             "record": {
#                 "$type": "app.bsky.feed.post",
#                 "createdAt": "2024-12-07T17:23:35.359550+01:00",
#                 "text": "Hello BlueSky!"
#             },
#             "replyCount": 0,
#             "repostCount": 0,
#             "likeCount": 0,
#             "quoteCount": 0,
#             "indexedAt": "2024-12-07T16:23:36.356Z",
#             "viewer": {
#                 "threadMuted": false,
#                 "embeddingDisabled": false
#             },
#             "labels": []
#         }
#     },
#     {
#         "post": {
#             "uri": "at://did:plc:f6fle6xy5s4epqamivy45kfm/app.bsky.feed.post/3lcpt5aahsy25",
#             "cid": "bafyreifczmp4wwxnmyaenp76gwpbzbh3pxrddckxctxlvqwkjlsghztd4y",
#             "author": {
#                 "did": "did:plc:f6fle6xy5s4epqamivy45kfm",
#                 "handle": "mechfortuneteller.bsky.social",
#                 "displayName": "",
#                 "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:f6fle6xy5s4epqamivy45kfm/bafkreiak7eaknki3ulkp4zqudfq2zymfnklchqam3leapdv4zxbrbavz7u@jpeg",
#                 "viewer": {
#                     "muted": false,
#                     "blockedBy": false
#                 },
#                 "labels": [],
#                 "createdAt": "2024-12-01T09:40:56.046Z"
#             },
#             "record": {
#                 "$type": "app.bsky.feed.post",
#                 "createdAt": "2024-12-07T14:40:29.815194+01:00",
#                 "text": "Hello BlueSky!"
#             },
#             "replyCount": 0,
#             "repostCount": 0,
#             "likeCount": 0,
#             "quoteCount": 0,
#             "indexedAt": "2024-12-07T13:40:30.852Z",
#             "viewer": {
#                 "threadMuted": false,
#                 "embeddingDisabled": false
#             },
#             "labels": []
#         }
#     },
#     {
#         "post": {
#             "uri": "at://did:plc:z72i7hdynmk6r22z27h6tvur/app.bsky.feed.post/3lcfsxfgmpk2q",
#             "cid": "bafyreib4ks4iqvjqgqbfligadpgbwaipir3m7ibr54oudygp6w5ffnta5q",
#             "author": {
#                 "did": "did:plc:z72i7hdynmk6r22z27h6tvur",
#                 "handle": "bsky.app",
#                 "displayName": "Bluesky",
#                 "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:z72i7hdynmk6r22z27h6tvur/bafkreihagr2cmvl2jt4mgx3sppwe2it3fwolkrbtjrhcnwjk4jdijhsoze@jpeg",
#                 "associated": {
#                     "chat": {
#                         "allowIncoming": "none"
#                     }
#                 },
#                 "viewer": {
#                     "muted": false,
#                     "blockedBy": false,
#                     "following": "at://did:plc:f6fle6xy5s4epqamivy45kfm/app.bsky.graph.follow/3lcacxaij622r"
#                 },
#                 "labels": [],
#                 "createdAt": "2023-04-12T04:53:57.057Z"
#             },
#             "record": {
#                 "$type": "app.bsky.feed.post",
#                 "createdAt": "2024-12-03T14:10:36.867Z",
#                 "embed": {
#                     "$type": "app.bsky.embed.external",
#                     "external": {
#                         "description": "Now, scientists and researchers can more easily track conversation around their research.",
#                         "thumb": {
#                             "$type": "blob",
#                             "ref": {
#                                 "$link": "bafkreif5bxpqjyyjmsqphbuvloo5c7ieqqs54i4wychem2ebvpw7uaxasy"
#                             },
#                             "mimeType": "image/jpeg",
#                             "size": 502451
#                         },
#                         "title": "Altmetric Is Now Tracking Bluesky Mentions! - Bluesky",
#                         "uri": "https://bsky.social/about/blog/12-03-2024-altmetric"
#                     }
#                 },
#                 "facets": [
#                     {
#                         "$type": "app.bsky.richtext.facet",
#                         "features": [
#                             {
#                                 "$type": "app.bsky.richtext.facet#mention",
#                                 "did": "did:plc:lf4a2b6djtuv5l3lz7ffsyv4"
#                             }
#                         ],
#                         "index": {
#                             "byteEnd": 31,
#                             "byteStart": 17
#                         }
#                     }
#                 ],
#                 "langs": [
#                     "en"
#                 ],
#                 "reply": {
#                     "parent": {
#                         "cid": "bafyreie7jwnrhm6djlqtxjycny4b6wz25o6oiawemqij6smjaat3mhq7ue",
#                         "uri": "at://did:plc:z72i7hdynmk6r22z27h6tvur/app.bsky.feed.post/3lcfsxeylik2q"
#                     },
#                     "root": {
#                         "cid": "bafyreie7jwnrhm6djlqtxjycny4b6wz25o6oiawemqij6smjaat3mhq7ue",
#                         "uri": "at://did:plc:z72i7hdynmk6r22z27h6tvur/app.bsky.feed.post/3lcfsxeylik2q"
#                     }
#                 },
#                 "text": "Learn more about @altmetric.com's Bluesky integration:"
#             },
#             "embed": {
#                 "$type": "app.bsky.embed.external#view",
#                 "external": {
#                     "uri": "https://bsky.social/about/blog/12-03-2024-altmetric",
#                     "title": "Altmetric Is Now Tracking Bluesky Mentions! - Bluesky",
#                     "description": "Now, scientists and researchers can more easily track conversation around their research.",
#                     "thumb": "https://cdn.bsky.app/img/feed_thumbnail/plain/did:plc:z72i7hdynmk6r22z27h6tvur/bafkreif5bxpqjyyjmsqphbuvloo5c7ieqqs54i4wychem2ebvpw7uaxasy@jpeg"
#                 }
#             },
#             "replyCount": 52,
#             "repostCount": 115,
#             "likeCount": 1850,
#             "quoteCount": 9,
#             "indexedAt": "2024-12-03T14:17:17.716Z",
#             "viewer": {
#                 "threadMuted": false,
#                 "embeddingDisabled": false
#             },
#             "labels": []
#         },
#         "reply": {
#             "root": {
#                 "$type": "app.bsky.feed.defs#postView",
#                 "uri": "at://did:plc:z72i7hdynmk6r22z27h6tvur/app.bsky.feed.post/3lcfsxeylik2q",
#                 "cid": "bafyreie7jwnrhm6djlqtxjycny4b6wz25o6oiawemqij6smjaat3mhq7ue",
#                 "author": {
#                     "did": "did:plc:z72i7hdynmk6r22z27h6tvur",
#                     "handle": "bsky.app",
#                     "displayName": "Bluesky",
#                     "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:z72i7hdynmk6r22z27h6tvur/bafkreihagr2cmvl2jt4mgx3sppwe2it3fwolkrbtjrhcnwjk4jdijhsoze@jpeg",
#                     "associated": {
#                         "chat": {
#                             "allowIncoming": "none"
#                         }
#                     },
#                     "viewer": {
#                         "muted": false,
#                         "blockedBy": false,
#                         "following": "at://did:plc:f6fle6xy5s4epqamivy45kfm/app.bsky.graph.follow/3lcacxaij622r"
#                     },
#                     "labels": [],
#                     "createdAt": "2023-04-12T04:53:57.057Z"
#                 },
#                 "record": {
#                     "$type": "app.bsky.feed.post",
#                     "createdAt": "2024-12-03T14:10:36.866Z",
#                     "embed": {
#                         "$type": "app.bsky.embed.record",
#                         "record": {
#                             "cid": "bafyreih3v4gjntienrwflikf7udyv7aaesd5ghcckfyknqxqckuiaqwm2m",
#                             "uri": "at://did:plc:lf4a2b6djtuv5l3lz7ffsyv4/app.bsky.feed.post/3lcfsg3qj5f23"
#                         }
#                     },
#                     "facets": [
#                         {
#                             "$type": "app.bsky.richtext.facet",
#                             "features": [
#                                 {
#                                     "$type": "app.bsky.richtext.facet#mention",
#                                     "did": "did:plc:lf4a2b6djtuv5l3lz7ffsyv4"
#                                 }
#                             ],
#                             "index": {
#                                 "byteEnd": 80,
#                                 "byteStart": 66
#                             }
#                         }
#                     ],
#                     "langs": [
#                         "en"
#                     ],
#                     "text": "Scientists, academics, researchers: We\u2019re excited to share that @altmetric.com is now tracking mentions of your research on Bluesky! \ud83e\uddea"
#                 },
#                 "embed": {
#                     "$type": "app.bsky.embed.record#view",
#                     "record": {
#                         "$type": "app.bsky.embed.record#viewRecord",
#                         "uri": "at://did:plc:lf4a2b6djtuv5l3lz7ffsyv4/app.bsky.feed.post/3lcfsg3qj5f23",
#                         "cid": "bafyreih3v4gjntienrwflikf7udyv7aaesd5ghcckfyknqxqckuiaqwm2m",
#                         "author": {
#                             "did": "did:plc:lf4a2b6djtuv5l3lz7ffsyv4",
#                             "handle": "altmetric.com",
#                             "displayName": "Altmetric",
#                             "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:lf4a2b6djtuv5l3lz7ffsyv4/bafkreidgzx42rzsswlncj63uve6ui7ifg6zmzewgfrbq7l2lg2vyfnsb6m@jpeg",
#                             "associated": {
#                                 "chat": {
#                                     "allowIncoming": "all"
#                                 }
#                             },
#                             "viewer": {
#                                 "muted": false,
#                                 "blockedBy": false
#                             },
#                             "labels": [],
#                             "createdAt": "2023-09-20T16:15:51.521Z"
#                         },
#                         "value": {
#                             "$type": "app.bsky.feed.post",
#                             "createdAt": "2024-12-03T14:00:56.000Z",
#                             "embed": {
#                                 "$type": "app.bsky.embed.images",
#                                 "images": [
#                                     {
#                                         "alt": "\u2018A place of joy\u2019: why scientists are joining the rush to Bluesky\nResearchers say the social-media platform \u2014 an alternative to X \u2014 offers more control over the content they see and the people they engage with.: https://www.nature.com/articles/d41586-024-03784-6",
#                                         "aspectRatio": {
#                                             "height": 888,
#                                             "width": 1557
#                                         },
#                                         "image": {
#                                             "$type": "blob",
#                                             "ref": {
#                                                 "$link": "bafkreiawiekmql2zmt7dzisodqnzs7evacfetqfd2lkmukpw5hm2tedrs4"
#                                             },
#                                             "mimeType": "image/png",
#                                             "size": 186639
#                                         }
#                                     }
#                                 ]
#                             },
#                             "langs": [],
#                             "reply": {
#                                 "parent": {
#                                     "cid": "bafyreiftghtt2qidkv5ltsqb4jm6bvwk2hkc3bykvor6wc4hot36ejiktu",
#                                     "uri": "at://did:plc:lf4a2b6djtuv5l3lz7ffsyv4/app.bsky.feed.post/3lcfsfwk33g2m"
#                                 },
#                                 "root": {
#                                     "cid": "bafyreiasu363odagbbp2p2p6nejroqpeodxgl53aqzhpvfsk4azke5lf3q",
#                                     "uri": "at://did:plc:lf4a2b6djtuv5l3lz7ffsyv4/app.bsky.feed.post/3lcfsenzf552i"
#                                 }
#                             },
#                             "text": "There are already many articles for which there is more attention on Bluesky than on other comparable micro-blogging sites, meaning the academic community and the general public have clearly adopted Bluesky as one of its core places to disseminate and discuss new research.\n\nA Place of Joy."
#                         },
#                         "labels": [],
#                         "likeCount": 2327,
#                         "replyCount": 42,
#                         "repostCount": 614,
#                         "quoteCount": 95,
#                         "indexedAt": "2024-12-03T14:00:57.555Z",
#                         "embeds": [
#                             {
#                                 "$type": "app.bsky.embed.images#view",
#                                 "images": [
#                                     {
#                                         "thumb": "https://cdn.bsky.app/img/feed_thumbnail/plain/did:plc:lf4a2b6djtuv5l3lz7ffsyv4/bafkreiawiekmql2zmt7dzisodqnzs7evacfetqfd2lkmukpw5hm2tedrs4@jpeg",
#                                         "fullsize": "https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:lf4a2b6djtuv5l3lz7ffsyv4/bafkreiawiekmql2zmt7dzisodqnzs7evacfetqfd2lkmukpw5hm2tedrs4@jpeg",
#                                         "alt": "\u2018A place of joy\u2019: why scientists are joining the rush to Bluesky\nResearchers say the social-media platform \u2014 an alternative to X \u2014 offers more control over the content they see and the people they engage with.: https://www.nature.com/articles/d41586-024-03784-6",
#                                         "aspectRatio": {
#                                             "height": 888,
#                                             "width": 1557
#                                         }
#                                     }
#                                 ]
#                             }
#                         ]
#                     }
#                 },
#                 "replyCount": 353,
#                 "repostCount": 4739,
#                 "likeCount": 27666,
#                 "quoteCount": 247,
#                 "indexedAt": "2024-12-03T14:10:39.363Z",
#                 "viewer": {
#                     "threadMuted": false,
#                     "embeddingDisabled": false
#                 },
#                 "labels": []
#             },
#             "parent": {
#                 "$type": "app.bsky.feed.defs#postView",
#                 "uri": "at://did:plc:z72i7hdynmk6r22z27h6tvur/app.bsky.feed.post/3lcfsxeylik2q",
#                 "cid": "bafyreie7jwnrhm6djlqtxjycny4b6wz25o6oiawemqij6smjaat3mhq7ue",
#                 "author": {
#                     "did": "did:plc:z72i7hdynmk6r22z27h6tvur",
#                     "handle": "bsky.app",
#                     "displayName": "Bluesky",
#                     "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:z72i7hdynmk6r22z27h6tvur/bafkreihagr2cmvl2jt4mgx3sppwe2it3fwolkrbtjrhcnwjk4jdijhsoze@jpeg",
#                     "associated": {
#                         "chat": {
#                             "allowIncoming": "none"
#                         }
#                     },
#                     "viewer": {
#                         "muted": false,
#                         "blockedBy": false,
#                         "following": "at://did:plc:f6fle6xy5s4epqamivy45kfm/app.bsky.graph.follow/3lcacxaij622r"
#                     },
#                     "labels": [],
#                     "createdAt": "2023-04-12T04:53:57.057Z"
#                 },
#                 "record": {
#                     "$type": "app.bsky.feed.post",
#                     "createdAt": "2024-12-03T14:10:36.866Z",
#                     "embed": {
#                         "$type": "app.bsky.embed.record",
#                         "record": {
#                             "cid": "bafyreih3v4gjntienrwflikf7udyv7aaesd5ghcckfyknqxqckuiaqwm2m",
#                             "uri": "at://did:plc:lf4a2b6djtuv5l3lz7ffsyv4/app.bsky.feed.post/3lcfsg3qj5f23"
#                         }
#                     },
#                     "facets": [
#                         {
#                             "$type": "app.bsky.richtext.facet",
#                             "features": [
#                                 {
#                                     "$type": "app.bsky.richtext.facet#mention",
#                                     "did": "did:plc:lf4a2b6djtuv5l3lz7ffsyv4"
#                                 }
#                             ],
#                             "index": {
#                                 "byteEnd": 80,
#                                 "byteStart": 66
#                             }
#                         }
#                     ],
#                     "langs": [
#                         "en"
#                     ],
#                     "text": "Scientists, academics, researchers: We\u2019re excited to share that @altmetric.com is now tracking mentions of your research on Bluesky! \ud83e\uddea"
#                 },
#                 "embed": {
#                     "$type": "app.bsky.embed.record#view",
#                     "record": {
#                         "$type": "app.bsky.embed.record#viewRecord",
#                         "uri": "at://did:plc:lf4a2b6djtuv5l3lz7ffsyv4/app.bsky.feed.post/3lcfsg3qj5f23",
#                         "cid": "bafyreih3v4gjntienrwflikf7udyv7aaesd5ghcckfyknqxqckuiaqwm2m",
#                         "author": {
#                             "did": "did:plc:lf4a2b6djtuv5l3lz7ffsyv4",
#                             "handle": "altmetric.com",
#                             "displayName": "Altmetric",
#                             "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:lf4a2b6djtuv5l3lz7ffsyv4/bafkreidgzx42rzsswlncj63uve6ui7ifg6zmzewgfrbq7l2lg2vyfnsb6m@jpeg",
#                             "associated": {
#                                 "chat": {
#                                     "allowIncoming": "all"
#                                 }
#                             },
#                             "viewer": {
#                                 "muted": false,
#                                 "blockedBy": false
#                             },
#                             "labels": [],
#                             "createdAt": "2023-09-20T16:15:51.521Z"
#                         },
#                         "value": {
#                             "$type": "app.bsky.feed.post",
#                             "createdAt": "2024-12-03T14:00:56.000Z",
#                             "embed": {
#                                 "$type": "app.bsky.embed.images",
#                                 "images": [
#                                     {
#                                         "alt": "\u2018A place of joy\u2019: why scientists are joining the rush to Bluesky\nResearchers say the social-media platform \u2014 an alternative to X \u2014 offers more control over the content they see and the people they engage with.: https://www.nature.com/articles/d41586-024-03784-6",
#                                         "aspectRatio": {
#                                             "height": 888,
#                                             "width": 1557
#                                         },
#                                         "image": {
#                                             "$type": "blob",
#                                             "ref": {
#                                                 "$link": "bafkreiawiekmql2zmt7dzisodqnzs7evacfetqfd2lkmukpw5hm2tedrs4"
#                                             },
#                                             "mimeType": "image/png",
#                                             "size": 186639
#                                         }
#                                     }
#                                 ]
#                             },
#                             "langs": [],
#                             "reply": {
#                                 "parent": {
#                                     "cid": "bafyreiftghtt2qidkv5ltsqb4jm6bvwk2hkc3bykvor6wc4hot36ejiktu",
#                                     "uri": "at://did:plc:lf4a2b6djtuv5l3lz7ffsyv4/app.bsky.feed.post/3lcfsfwk33g2m"
#                                 },
#                                 "root": {
#                                     "cid": "bafyreiasu363odagbbp2p2p6nejroqpeodxgl53aqzhpvfsk4azke5lf3q",
#                                     "uri": "at://did:plc:lf4a2b6djtuv5l3lz7ffsyv4/app.bsky.feed.post/3lcfsenzf552i"
#                                 }
#                             },
#                             "text": "There are already many articles for which there is more attention on Bluesky than on other comparable micro-blogging sites, meaning the academic community and the general public have clearly adopted Bluesky as one of its core places to disseminate and discuss new research.\n\nA Place of Joy."
#                         },
#                         "labels": [],
#                         "likeCount": 2327,
#                         "replyCount": 42,
#                         "repostCount": 614,
#                         "quoteCount": 95,
#                         "indexedAt": "2024-12-03T14:00:57.555Z",
#                         "embeds": [
#                             {
#                                 "$type": "app.bsky.embed.images#view",
#                                 "images": [
#                                     {
#                                         "thumb": "https://cdn.bsky.app/img/feed_thumbnail/plain/did:plc:lf4a2b6djtuv5l3lz7ffsyv4/bafkreiawiekmql2zmt7dzisodqnzs7evacfetqfd2lkmukpw5hm2tedrs4@jpeg",
#                                         "fullsize": "https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:lf4a2b6djtuv5l3lz7ffsyv4/bafkreiawiekmql2zmt7dzisodqnzs7evacfetqfd2lkmukpw5hm2tedrs4@jpeg",
#                                         "alt": "\u2018A place of joy\u2019: why scientists are joining the rush to Bluesky\nResearchers say the social-media platform \u2014 an alternative to X \u2014 offers more control over the content they see and the people they engage with.: https://www.nature.com/articles/d41586-024-03784-6",
#                                         "aspectRatio": {
#                                             "height": 888,
#                                             "width": 1557
#                                         }
#                                     }
#                                 ]
#                             }
#                         ]
#                     }
#                 },
#                 "replyCount": 353,
#                 "repostCount": 4739,
#                 "likeCount": 27666,
#                 "quoteCount": 247,
#                 "indexedAt": "2024-12-03T14:10:39.363Z",
#                 "viewer": {
#                     "threadMuted": false,
#                     "embeddingDisabled": false
#                 },
#                 "labels": []
#             }
#         }
#     },
#     {
#         "post": {
#             "uri": "at://did:plc:z72i7hdynmk6r22z27h6tvur/app.bsky.feed.post/3lcfsxeylik2q",
#             "cid": "bafyreie7jwnrhm6djlqtxjycny4b6wz25o6oiawemqij6smjaat3mhq7ue",
#             "author": {
#                 "did": "did:plc:z72i7hdynmk6r22z27h6tvur",
#                 "handle": "bsky.app",
#                 "displayName": "Bluesky",
#                 "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:z72i7hdynmk6r22z27h6tvur/bafkreihagr2cmvl2jt4mgx3sppwe2it3fwolkrbtjrhcnwjk4jdijhsoze@jpeg",
#                 "associated": {
#                     "chat": {
#                         "allowIncoming": "none"
#                     }
#                 },
#                 "viewer": {
#                     "muted": false,
#                     "blockedBy": false,
#                     "following": "at://did:plc:f6fle6xy5s4epqamivy45kfm/app.bsky.graph.follow/3lcacxaij622r"
#                 },
#                 "labels": [],
#                 "createdAt": "2023-04-12T04:53:57.057Z"
#             },
#             "record": {
#                 "$type": "app.bsky.feed.post",
#                 "createdAt": "2024-12-03T14:10:36.866Z",
#                 "embed": {
#                     "$type": "app.bsky.embed.record",
#                     "record": {
#                         "cid": "bafyreih3v4gjntienrwflikf7udyv7aaesd5ghcckfyknqxqckuiaqwm2m",
#                         "uri": "at://did:plc:lf4a2b6djtuv5l3lz7ffsyv4/app.bsky.feed.post/3lcfsg3qj5f23"
#                     }
#                 },
#                 "facets": [
#                     {
#                         "$type": "app.bsky.richtext.facet",
#                         "features": [
#                             {
#                                 "$type": "app.bsky.richtext.facet#mention",
#                                 "did": "did:plc:lf4a2b6djtuv5l3lz7ffsyv4"
#                             }
#                         ],
#                         "index": {
#                             "byteEnd": 80,
#                             "byteStart": 66
#                         }
#                     }
#                 ],
#                 "langs": [
#                     "en"
#                 ],
#                 "text": "Scientists, academics, researchers: We\u2019re excited to share that @altmetric.com is now tracking mentions of your research on Bluesky! \ud83e\uddea"
#             },
#             "embed": {
#                 "$type": "app.bsky.embed.record#view",
#                 "record": {
#                     "$type": "app.bsky.embed.record#viewRecord",
#                     "uri": "at://did:plc:lf4a2b6djtuv5l3lz7ffsyv4/app.bsky.feed.post/3lcfsg3qj5f23",
#                     "cid": "bafyreih3v4gjntienrwflikf7udyv7aaesd5ghcckfyknqxqckuiaqwm2m",
#                     "author": {
#                         "did": "did:plc:lf4a2b6djtuv5l3lz7ffsyv4",
#                         "handle": "altmetric.com",
#                         "displayName": "Altmetric",
#                         "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:lf4a2b6djtuv5l3lz7ffsyv4/bafkreidgzx42rzsswlncj63uve6ui7ifg6zmzewgfrbq7l2lg2vyfnsb6m@jpeg",
#                         "associated": {
#                             "chat": {
#                                 "allowIncoming": "all"
#                             }
#                         },
#                         "viewer": {
#                             "muted": false,
#                             "blockedBy": false
#                         },
#                         "labels": [],
#                         "createdAt": "2023-09-20T16:15:51.521Z"
#                     },
#                     "value": {
#                         "$type": "app.bsky.feed.post",
#                         "createdAt": "2024-12-03T14:00:56.000Z",
#                         "embed": {
#                             "$type": "app.bsky.embed.images",
#                             "images": [
#                                 {
#                                     "alt": "\u2018A place of joy\u2019: why scientists are joining the rush to Bluesky\nResearchers say the social-media platform \u2014 an alternative to X \u2014 offers more control over the content they see and the people they engage with.: https://www.nature.com/articles/d41586-024-03784-6",
#                                     "aspectRatio": {
#                                         "height": 888,
#                                         "width": 1557
#                                     },
#                                     "image": {
#                                         "$type": "blob",
#                                         "ref": {
#                                             "$link": "bafkreiawiekmql2zmt7dzisodqnzs7evacfetqfd2lkmukpw5hm2tedrs4"
#                                         },
#                                         "mimeType": "image/png",
#                                         "size": 186639
#                                     }
#                                 }
#                             ]
#                         },
#                         "langs": [],
#                         "reply": {
#                             "parent": {
#                                 "cid": "bafyreiftghtt2qidkv5ltsqb4jm6bvwk2hkc3bykvor6wc4hot36ejiktu",
#                                 "uri": "at://did:plc:lf4a2b6djtuv5l3lz7ffsyv4/app.bsky.feed.post/3lcfsfwk33g2m"
#                             },
#                             "root": {
#                                 "cid": "bafyreiasu363odagbbp2p2p6nejroqpeodxgl53aqzhpvfsk4azke5lf3q",
#                                 "uri": "at://did:plc:lf4a2b6djtuv5l3lz7ffsyv4/app.bsky.feed.post/3lcfsenzf552i"
#                             }
#                         },
#                         "text": "There are already many articles for which there is more attention on Bluesky than on other comparable micro-blogging sites, meaning the academic community and the general public have clearly adopted Bluesky as one of its core places to disseminate and discuss new research.\n\nA Place of Joy."
#                     },
#                     "labels": [],
#                     "likeCount": 2327,
#                     "replyCount": 42,
#                     "repostCount": 614,
#                     "quoteCount": 95,
#                     "indexedAt": "2024-12-03T14:00:57.555Z",
#                     "embeds": [
#                         {
#                             "$type": "app.bsky.embed.images#view",
#                             "images": [
#                                 {
#                                     "thumb": "https://cdn.bsky.app/img/feed_thumbnail/plain/did:plc:lf4a2b6djtuv5l3lz7ffsyv4/bafkreiawiekmql2zmt7dzisodqnzs7evacfetqfd2lkmukpw5hm2tedrs4@jpeg",
#                                     "fullsize": "https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:lf4a2b6djtuv5l3lz7ffsyv4/bafkreiawiekmql2zmt7dzisodqnzs7evacfetqfd2lkmukpw5hm2tedrs4@jpeg",
#                                     "alt": "\u2018A place of joy\u2019: why scientists are joining the rush to Bluesky\nResearchers say the social-media platform \u2014 an alternative to X \u2014 offers more control over the content they see and the people they engage with.: https://www.nature.com/articles/d41586-024-03784-6",
#                                     "aspectRatio": {
#                                         "height": 888,
#                                         "width": 1557
#                                     }
#                                 }
#                             ]
#                         }
#                     ]
#                 }
#             },
#             "replyCount": 353,
#             "repostCount": 4739,
#             "likeCount": 27666,
#             "quoteCount": 247,
#             "indexedAt": "2024-12-03T14:10:39.363Z",
#             "viewer": {
#                 "threadMuted": false,
#                 "embeddingDisabled": false
#             },
#             "labels": []
#         }
#     },
#     {
#         "post": {
#             "uri": "at://did:plc:f6fle6xy5s4epqamivy45kfm/app.bsky.feed.post/3lcaf44ezzl2y",
#             "cid": "bafyreicucpc2m56lrhbxahtmrquf6drnhrxrgilulxiuq7tjvdo2wp26ha",
#             "author": {
#                 "did": "did:plc:f6fle6xy5s4epqamivy45kfm",
#                 "handle": "mechfortuneteller.bsky.social",
#                 "displayName": "",
#                 "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:f6fle6xy5s4epqamivy45kfm/bafkreiak7eaknki3ulkp4zqudfq2zymfnklchqam3leapdv4zxbrbavz7u@jpeg",
#                 "viewer": {
#                     "muted": false,
#                     "blockedBy": false
#                 },
#                 "labels": [],
#                 "createdAt": "2024-12-01T09:40:56.046Z"
#             },
#             "record": {
#                 "$type": "app.bsky.feed.post",
#                 "createdAt": "2024-12-01T10:19:23.960677+00:00",
#                 "langs": [
#                     "en"
#                 ],
#                 "text": "Hello world! I posted this via the Python SDK."
#             },
#             "replyCount": 0,
#             "repostCount": 0,
#             "likeCount": 2,
#             "quoteCount": 0,
#             "indexedAt": "2024-12-01T10:19:24.949Z",
#             "viewer": {
#                 "threadMuted": false,
#                 "embeddingDisabled": false
#             },
#             "labels": []
#         }
#     },
#     {
#         "post": {
#             "uri": "at://did:plc:z72i7hdynmk6r22z27h6tvur/app.bsky.feed.post/3lc4n2cohf22a",
#             "cid": "bafyreicv7ctm6f3sg5pnfq3klufrb56pakkhyxqhbm7tcy7hbaicamwfwa",
#             "author": {
#                 "did": "did:plc:z72i7hdynmk6r22z27h6tvur",
#                 "handle": "bsky.app",
#                 "displayName": "Bluesky",
#                 "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:z72i7hdynmk6r22z27h6tvur/bafkreihagr2cmvl2jt4mgx3sppwe2it3fwolkrbtjrhcnwjk4jdijhsoze@jpeg",
#                 "associated": {
#                     "chat": {
#                         "allowIncoming": "none"
#                     }
#                 },
#                 "viewer": {
#                     "muted": false,
#                     "blockedBy": false,
#                     "following": "at://did:plc:f6fle6xy5s4epqamivy45kfm/app.bsky.graph.follow/3lcacxaij622r"
#                 },
#                 "labels": [],
#                 "createdAt": "2023-04-12T04:53:57.057Z"
#             },
#             "record": {
#                 "$type": "app.bsky.feed.post",
#                 "createdAt": "2024-11-29T22:30:55.003Z",
#                 "embed": {
#                     "$type": "app.bsky.embed.external",
#                     "external": {
#                         "description": "Bluesky is the lobby to the open web. Find and build your community here.",
#                         "thumb": {
#                             "$type": "blob",
#                             "ref": {
#                                 "$link": "bafkreif5bxpqjyyjmsqphbuvloo5c7ieqqs54i4wychem2ebvpw7uaxasy"
#                             },
#                             "mimeType": "image/jpeg",
#                             "size": 502451
#                         },
#                         "title": "The Engagement Is Better on Bluesky - Bluesky",
#                         "uri": "https://bsky.social/about/blog/11-29-2024-engagement"
#                     }
#                 },
#                 "langs": [
#                     "en"
#                 ],
#                 "text": "We could go on about how we welcome publishers, we don't demote links, we encourage independent developers to build apps and extensions on top of Bluesky's network.... but instead, we'll show you. \n\nAll thanks to the incredible community here! \ud83e\udd8b"
#             },
#             "embed": {
#                 "$type": "app.bsky.embed.external#view",
#                 "external": {
#                     "uri": "https://bsky.social/about/blog/11-29-2024-engagement",
#                     "title": "The Engagement Is Better on Bluesky - Bluesky",
#                     "description": "Bluesky is the lobby to the open web. Find and build your community here.",
#                     "thumb": "https://cdn.bsky.app/img/feed_thumbnail/plain/did:plc:z72i7hdynmk6r22z27h6tvur/bafkreif5bxpqjyyjmsqphbuvloo5c7ieqqs54i4wychem2ebvpw7uaxasy@jpeg"
#                 }
#             },
#             "replyCount": 1407,
#             "repostCount": 8734,
#             "likeCount": 75993,
#             "quoteCount": 472,
#             "indexedAt": "2024-11-29T22:30:56.754Z",
#             "viewer": {
#                 "threadMuted": false,
#                 "embeddingDisabled": false
#             },
#             "labels": []
#         }
#     }
# ]

# %%
# Loop through the response and extract required data
for item in feed:
    post = item.get('post', {})
    
    # Extract the required fields
    uri = post.get('uri')
    author_did = post.get('author', {}).get('did')
    created_at = post.get('record', {}).get('createdAt')
    text = post.get('record', {}).get('text')
    
    # Print the extracted details
    print(f"Post URI: {uri}")
    print(f"Author DID: {author_did}")
    print(f"Post Created At: {created_at}")
    print(f"Post Text: {text}")
    print("-" * 40)
# Out:
# Post URI: at://did:plc:f6fle6xy5s4epqamivy45kfm/app.bsky.feed.post/3lcq4auf6t22m
# Author DID: did:plc:f6fle6xy5s4epqamivy45kfm
# Post Created At: 2024-12-07T17:23:35.359550+01:00
# Post Text: Hello BlueSky!
# ----------------------------------------
# Post URI: at://did:plc:f6fle6xy5s4epqamivy45kfm/app.bsky.feed.post/3lcpt5aahsy25
# Author DID: did:plc:f6fle6xy5s4epqamivy45kfm
# Post Created At: 2024-12-07T14:40:29.815194+01:00
# Post Text: Hello BlueSky!
# ----------------------------------------
# Post URI: at://did:plc:z72i7hdynmk6r22z27h6tvur/app.bsky.feed.post/3lcfsxfgmpk2q
# Author DID: did:plc:z72i7hdynmk6r22z27h6tvur
# Post Created At: 2024-12-03T14:10:36.867Z
# Post Text: Learn more about @altmetric.com's Bluesky integration:
# ----------------------------------------
# Post URI: at://did:plc:z72i7hdynmk6r22z27h6tvur/app.bsky.feed.post/3lcfsxeylik2q
# Author DID: did:plc:z72i7hdynmk6r22z27h6tvur
# Post Created At: 2024-12-03T14:10:36.866Z
# Post Text: Scientists, academics, researchers: We’re excited to share that @altmetric.com is now tracking mentions of your research on Bluesky! 🧪
# ----------------------------------------
# Post URI: at://did:plc:f6fle6xy5s4epqamivy45kfm/app.bsky.feed.post/3lcaf44ezzl2y
# Author DID: did:plc:f6fle6xy5s4epqamivy45kfm
# Post Created At: 2024-12-01T10:19:23.960677+00:00
# Post Text: Hello world! I posted this via the Python SDK.
# ----------------------------------------
# Post URI: at://did:plc:z72i7hdynmk6r22z27h6tvur/app.bsky.feed.post/3lc4n2cohf22a
# Author DID: did:plc:z72i7hdynmk6r22z27h6tvur
# Post Created At: 2024-11-29T22:30:55.003Z
# Post Text: We could go on about how we welcome publishers, we don't demote links, we encourage independent developers to build apps and extensions on top of Bluesky's network.... but instead, we'll show you.
#
# All thanks to the incredible community here! 🦋
# ----------------------------------------
